# %% [markdown]
# EDA-(Exploratory Data Analysis): Understanding what is there inside the dataset.
# -Exploratory Data Analysis (EDA) is the process of analyzing and summarizing a dataset to understand its main characteristics before making any conclusions or building models. It helps you spot patterns, detect outliers, and check assumptions.
#
# In EDA, you often:
#
# Look at the data: Use tables, summaries (like average, median), and visualizations (like histograms, bar charts).
#
# Identify relationships: Explore how different variables relate (scatter plots or correlation).
#
# Clean the data: Detect and fix missing data, errors, or outliers.

# %% [raw]
# When working with a global warming dataset, the goal is often to understand trends related to climate change, carbon emissions, temperature variations, and other related factors.
#
# Here's an explanation of how you would approach the EDA process for a typical global warming dataset:

# %% [markdown]
# For the Dataset iam using Kaggle

# %% [raw]
# Step-1: Read and print head

# %%
#to read data we use pandas-first we import pandas
import pandas as pd
df=pd.read_csv("global warming.csv")
#to print head of the data
df.head()
# Out:
#          Country Name Country Code                          Indicator Name  \
# 0       United States          USA  CO2 emissions (metric tons per capita)
# 1      United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 2               India          IND  CO2 emissions (metric tons per capita)
# 3               China          CHN  CO2 emissions (metric tons per capita)
# 4  Russian Federation          RUS  CO2 emissions (metric tons per capita)
#
#    Indicator Code       2000       2001       2002       2003       2004  \
# 0  EN.ATM.CO2E.PC  20.178751  19.636505  19.613404  19.564105  19.658371
# 1  EN.ATM.CO2E.PC   9.199549   9.233175   8.904123   9.053278   8.989140
# 2  EN.ATM.CO2E.PC   0.979870   0.971698   0.967381   0.992392   1.025028
# 3  EN.ATM.CO2E.PC   2.696862   2.742121   3.007083   3.524074   4.037991
# 4  EN.ATM.CO2E.PC  10.627121  10.669603  10.715901  11.090647  11.120627
#
#         2005       2006       2007       2008       2009       2010  \
# ...

# %% [markdown]
# Step-2: Find the shape of the data.

# %%
df.shape#to find the shape (rows,columns)of the dataset
# Out:
# (15, 19)

# %% [markdown]
# Step-3: Find the information about the dataset.

# %%
df.info()#to find the information of the data
#note:in the output under Dtype object means stat
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Country Name    15 non-null     object
#  1   Country Code    15 non-null     object
#  2   Indicator Name  15 non-null     object
#  3   Indicator Code  15 non-null     object
#  4   2000            15 non-null     float64
#  5   2001            15 non-null     float64
#  6   2002            15 non-null     float64
#  7   2003            15 non-null     float64
#  8   2004            15 non-null     float64
#  9   2005            15 non-null     float64
#  10  2006            15 non-null     float64
#  11  2007            15 non-null     float64
#  12  2008            15 non-null     float64
#  13  2009            15 non-null     float64
#  14  2010            15 non-null     float64
#  15  2011            15 non-null     float64
#  16  2012            15 non-null     float64
# ...

# %% [markdown]
# step-4: Find duplicated rows

# %%
df.duplicated().value_counts()
# Out:
# False    15
# Name: count, dtype: int64

# %% [markdown]
# step-5: Drop duplicated rows

# %%
df=df.drop_duplicates()
df.duplicated().value_counts()
# Out:
# False    15
# Name: count, dtype: int64

# %% [markdown]
# Step-6: Find the basic stats of the data

# %%
# To find basic stats of the data.
df.describe()
# NOTE: When we use df.describe() it will give basic stats for only nuerical columns, it wont give for categorical columns.
# Out:
#             2000       2001       2002       2003       2004       2005  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    7.382051   7.304270   7.274428   7.390788   7.479159   7.505891
# std     6.770626   6.618440   6.630798   6.654608   6.608234   6.580783
# min     0.129282   0.135226   0.106877   0.113902   0.105477   0.120277
# 25%     1.425494   1.435026   1.405880   1.377437   1.426850   1.463326
# 50%     5.946665   6.153061   6.068664   6.115998   6.120079   6.099599
# 75%    10.361380  10.517945  10.387287  10.530001  10.514915  10.476206
# max    20.178751  19.636505  19.613404  19.564105  19.658371  19.591885
#
#             2006       2007       2008       2009       2010       2011  \
# count  15.000000  15.000000  15.000000  15.000000  15.000000  15.000000
# mean    7.544299   7.564707   7.581381   7.200164   7.366153   7.344290
# std     6.505595   6.532978   6.447015   6.127030   6.103240   6.042883
# ...

# %% [markdown]
# Step-7: Find missing values(percentage optional)

# %%
# to find the number of missing values in every column
df.isnull().sum()
# Out:
# Country Name      0
# Country Code      0
# Indicator Name    0
# Indicator Code    0
# 2000              0
# 2001              0
# 2002              0
# 2003              0
# 2004              0
# 2005              0
# 2006              0
# 2007              0
# 2008              0
# 2009              0
# 2010              0
# 2011              0
# 2012              0
# 2013              0
# 2014              0
# dtype: int64

# %% [markdown]
# In percentage(optional)

# %%
#to find the missing values in every column in percentage.
df.isnull().sum()/len(df)*100
# Out:
# Country Name      0.0
# Country Code      0.0
# Indicator Name    0.0
# Indicator Code    0.0
# 2000              0.0
# 2001              0.0
# 2002              0.0
# 2003              0.0
# 2004              0.0
# 2005              0.0
# 2006              0.0
# 2007              0.0
# 2008              0.0
# 2009              0.0
# 2010              0.0
# 2011              0.0
# 2012              0.0
# 2013              0.0
# 2014              0.0
# dtype: float64

# %% [markdown]
# Step-8: Find basic stats for categorical columns.

# %%
# to find basic stats for only categorical column
df.describe(include='object')
# Out:
#          Country Name Country Code                          Indicator Name  \
# count              15           15                                      15
# unique             15           15                                       1
# top     United States          USA  CO2 emissions (metric tons per capita)
# freq                1            1                                      15
#
#         Indicator Code
# count               15
# unique               1
# top     EN.ATM.CO2E.PC
# freq                15

# %% [markdown]
# Step-9: Find basic count analysis for categorical columns.

# %%
# to find the basic count values for categorical columns
#from above step we get to know what are the categorical columns
#the  count() method in pandas is used to count the number of non-null entries in dataframe or series
cat=['Country Name','Country Code','Indicator Name','Indicator Code']
for i in cat:
  print(i)
  print(df[i].value_counts())
  print('----------------')
  (df[cat].astype(str)=='?').any()
# Out:
# Country Name
# Country Name
# United States         1
# United Kingdom        1
# India                 1
# China                 1
# Russian Federation    1
# Australia             1
# France                1
# Germany               1
# Canada                1
# Brazil                1
# Argentina             1
# Pakistan              1
# Nepal                 1
# Bangladesh            1
# Japan                 1
# Name: count, dtype: int64
# ----------------
# Country Code
# Country Code
# USA    1
# GBR    1
# IND    1
# CHN    1
# RUS    1
# AUS    1
# FRA    1
# DEU    1
# CAN    1
# BRA    1
# ARG    1
# PAK    1
# NPL    1
# BGD    1
# JPN    1
# Name: count, dtype: int64
# ----------------
# Indicator Name
# Indicator Name
# CO2 emissions (metric tons per capita)    15
# Name: count, dtype: int64
# ----------------
# Indicator Code
# Indicator Code
# EN.ATM.CO2E.PC    15
# Name: count, dtype: int64
# ----------------

# %%
df=df.replace("?",pd.NA).dropna()#drop all ? marks from our dataset

# %%
(df[cat].astype(str)=='?').any()#displays all false, means no one ? mark
# Out:
# Country Name      False
# Country Code      False
# Indicator Name    False
# Indicator Code    False
# dtype: bool

# %%
# Load dataset
import seaborn as sns # for data visualization
import pandas as pd # for data analysis
import numpy as np # for numeric calculation
import matplotlib.pyplot as plt
globalWarming_df = pd.read_csv("global warming.csv")
globalWarming_df.head()
# Out:
#          Country Name Country Code                          Indicator Name  \
# 0       United States          USA  CO2 emissions (metric tons per capita)
# 1      United Kingdom          GBR  CO2 emissions (metric tons per capita)
# 2               India          IND  CO2 emissions (metric tons per capita)
# 3               China          CHN  CO2 emissions (metric tons per capita)
# 4  Russian Federation          RUS  CO2 emissions (metric tons per capita)
#
#    Indicator Code       2000       2001       2002       2003       2004  \
# 0  EN.ATM.CO2E.PC  20.178751  19.636505  19.613404  19.564105  19.658371
# 1  EN.ATM.CO2E.PC   9.199549   9.233175   8.904123   9.053278   8.989140
# 2  EN.ATM.CO2E.PC   0.979870   0.971698   0.967381   0.992392   1.025028
# 3  EN.ATM.CO2E.PC   2.696862   2.742121   3.007083   3.524074   4.037991
# 4  EN.ATM.CO2E.PC  10.627121  10.669603  10.715901  11.090647  11.120627
#
#         2005       2006       2007       2008       2009       2010  \
# ...

# %%
# set country name as index and drop Country Code, Indicator Name and Indicator Code
globalWarming_df  = globalWarming_df.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'], axis=1).set_index('Country Name')
globalWarming_df
# Create heatmap
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# change heatmap color using cmap
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, cmap="coolwarm")
# Out:
# <Axes: ylabel='Country Name'>

# %%
# robust
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, robust = True)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# annot (annotate) parameter
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, annot = True)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# linewidths parameter - divede each cell of heatmap
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, linewidths=4)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# linecolor parameter - change the color of heatmap line
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, linewidths=4, linecolor="k")
# Out:
# <Axes: ylabel='Country Name'>

# %%
# hide color bar with cbar parameter
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, cbar = False)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# change the shape of each cell in a square with squre parameter
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, linewidths = 1, square= True)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# change x-axis labels using xticklabels parameter
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df, xticklabels = np.arange(0,15))
# Out:
# <Axes: ylabel='Country Name'>

# %%
# change y-axis labels using yticklabels parameter
plt.figure(figsize=(16,9))
country_code = ['USA', 'GBR', 'IND', 'CHN', 'RUS', 'AUS', 'FRA', 'DEU', 'CAN', 'BRA', 'ARG', 'PAK', 'NPL', 'BGD', 'JPN']
sns.heatmap(globalWarming_df, yticklabels = country_code)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# create square box
plt.figure(figsize=(10,8))
sns.heatmap(globalWarming_df, xticklabels = False, yticklabels = False, cbar=False, linecolor="w", linewidths=1)
# Out:
# <Axes: ylabel='Country Name'>

# %%
# multiple heatmaps using subplots
plt.figure(figsize=(30,10))
plt.subplot(1,3,1) # first heatmap
sns.heatmap(globalWarming_df,  cbar=False, linecolor="w", linewidths=1)
plt.subplot(1,3,2) # second heatmap
sns.heatmap(globalWarming_df,  cbar=False, linecolor="k", linewidths=1)
plt.subplot(1,3,3) # third heatmap
sns.heatmap(globalWarming_df,  cbar=False, linecolor="y", linewidths=1)
plt.show()

# %%
# set seaborn heatmap title, x-axis, y-axis label and font size
plt.figure(figsize=(16,9))
ax = sns.heatmap(globalWarming_df)
ax.set(title="Heatmap",
      xlabel="Years",
      ylabel="Country Name",)
sns.set(font_scale=2) # set fontsize 2

# %%
# Heatmap with keyword arguments (kwargs) parameter
plt.figure(figsize = (16,9))
kwargs = {'alpha':.9,'linewidth':10, 'linestyle':'--', 'rasterized':False, 'edgecolor':'w',  "capstyle":'projecting',}
ax = sns.heatmap(globalWarming_df,**kwargs)

# %%
#How to create a seaborn heatmap using correlation matrix?
# sns heatmap correlation
plt.figure(figsize=(16,9))
sns.heatmap(globalWarming_df.corr(), annot = True)
# Out:
# <Axes: >

# %%
#Upper triangle seaborn heatmap with mask
# Upper triangle heatmap
plt.figure(figsize=(16,9))
corr_mx = globalWarming_df.corr() # correlation matrix
matrix = np.tril(corr_mx) # take lower correlation matrix
sns.heatmap(corr_mx, mask=matrix)
# Out:
# <Axes: >

# %%
# Lower triangle heatmap
plt.figure(figsize=(16,9))
corr_mx = globalWarming_df.corr() # correlation matrix
matrix = np.triu(corr_mx) # take upper correlation matrix
sns.heatmap(corr_mx, mask=matrix)
# Out:
# <Axes: >

# %%
#Seaborn heatmap examples for easy to use in the projects
# import libraries
import seaborn as sns # for data visualization
import matplotlib.pyplot as plt # for data visualization
import pandas as pd # for data analysis
 # load dataset and create DataFrame ready to create heatmap
globalWarming_df = pd.read_csv("global warming.csv")
globalWarming_df = globalWarming_df.drop(columns=['Country Code', 'Indicator Name', 'Indicator Code'], axis=1).set_index('Country Name')
# set heatmap size
plt.figure(figsize= (16,9))

# create heatmap seaborn
sns.heatmap(globalWarming_df)

plt.title("Heatmap for global warming", fontsize = 25)
plt.xlabel("CO2 emissions (metric tons per capita) Per Year", fontsize = 20)
plt.ylabel("Country Name", fontsize = 20)
plt.show()

# %% [markdown]
# Conclusion:
# EDA on a global warming dataset allows you to uncover important trends and relationships, and better understand the data before performing deeper statistical analysis or machine learning. By identifying patterns in temperature, CO2 emissions, and other relevant variables, EDA gives a solid foundation for further climate change studies or predictive modeling.
